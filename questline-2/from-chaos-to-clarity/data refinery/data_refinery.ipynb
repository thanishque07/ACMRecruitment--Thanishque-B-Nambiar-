# %%
import pandas as pd
df = pd.read_csv("StudentsPerformance.csv")

# %%
df.isnull().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum().sum()
df.duplicated().sum()
# Out:
# np.int64(0)
